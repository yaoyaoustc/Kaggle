# %% [markdown]
# # get libs ready

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import norm
from scipy import stats
# %run /Users/yaoyao/Documents/datascience/toolbox/toolbox1_dataview.ipynb
# %matplotlib inline

# %% [markdown]
# # read in training data

# %%
with open('train.csv') as f:
    df = pd.read_csv(f)
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
import seaborn as sns

# %%
sns.heatmap(df.corr()[['SalePrice']],vmin=-1,cmap='coolwarm',xticklabels=True, yticklabels=True,annot=True)

# %%
var = 'OverallQual'
data = pd.concat([df['SalePrice'], df[var]], axis=1)
sns.boxplot(x=var, y="SalePrice", data=data)

# %%
sns.set()
cols = ['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'TotalBsmtSF', 'FullBath', 'YearBuilt']
sns.pairplot(df[cols], height = 2.5)
plt.show()

# %%
from scipy.stats import norm
from scipy import stats
sns.distplot(df['SalePrice'],fit=norm);
fig = plt.figure()
res = stats.probplot(df['SalePrice'], plot=plt)

# %%
pd.options.display.max_rows = 60
basicinfo(df)
Y = df.iloc[:,80]
X = df.iloc[:,1:80]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            91 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# ...

# %%
# first discard no use features: no nonunique features
# second deal wtih nan's
'''LotFrontage       259 fill 0, conv2str
Alley            1369 fill 0
BsmtQual           37
BsmtCond           37
BsmtExposure       38
BsmtFinType1       37
BsmtFinType2       38
Electrical          1
FireplaceQu       690
GarageType         81
GarageYrBlt        81
GarageFinish       81
GarageQual         81
GarageCond         81
PoolQC           1453
Fence            1179
MiscFeature      1406 connected with MiscVal, can be dropped
'''
# Out:
# 'LotFrontage       259 fill 0, conv2str\nAlley            1369 fill 0\nBsmtQual           37\nBsmtCond           37\nBsmtExposure       38\nBsmtFinType1       37\nBsmtFinType2       38\nElectrical          1\nFireplaceQu       690\nGarageType         81\nGarageYrBlt        81\nGarageFinish       81\nGarageQual         81\nGarageCond         81\nPoolQC           1453\nFence            1179\nMiscFeature      1406 connected with MiscVal\n'

# %%
import pandas_profiling

# %%
pfr = pandas_profiling.ProfileReport(X)
pfr.to_file('report.html')
# Out:
# /Users/yaoyao/anaconda3/lib/python3.7/site-packages/pandas_profiling/model/correlations.py:124: UserWarning: There was an attempt to calculate the cramers correlation, but this failed.
# To hide this warning, disable the calculation
# (using `df.profile_report(correlations={"cramers": False}`)
# If this is problematic for your use case, please report this as an issue:
# https://github.com/pandas-profiling/pandas-profiling/issues
# (include the error message: 'The internally computed table of expected frequencies has a zero element at (0, 2).')
#   correlation_name=correlation_name, error=error

# %%
# a quikc and dirty benchmark
df_cp = df.fillna(0)
basicinfo(df_cp)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1460 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            1460 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# ...

# %% [markdown]
# # feature engineering

# %%
def drop_col(dataX,col_list):
    print(col_list)
    dataX2 = X.drop(columns=col_list)
    return dataX2

def X_classify(dataX):
    X_cata = X[X.columns[X.dtypes == object]]
    X_num = X[X.columns[X.dtypes != object]]
    return X_cata, X_num



def cata_process(X_cata):
    # deal with non: 
    X_cata_hasnan = X_cata[X_cata.columns[X_cata.isnull().sum() != 0]]
    X_cata_nonan = X_cata[X_cata.columns[X_cata.isnull().sum() == 0]]
    #some nons are meaningful, replace it with another category
    meaning_nan_list = ['Alley','BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2','FireplaceQu',
                    'GarageType','GarageFinish','GarageQual','GarageCond','PoolQC','Fence']
    X_cata_hasnan[meaning_nan_list].fillna('NP', inplace=True)
    #some nons can be leaved to dummy process
    leave_dummy_list = ['MasVnrType']
    #manulfit
    X_cata_hasnan['Electrical'].fillna('SBrkr', inplace=True)
    #convert to dummy
    X_cata_hasnan_dummy = pd.get_dummies(X_cata_hasnan)
    X_cata_nonan_dummy = pd.get_dummies(X_cata_nonan)
    # merge
    X_cata_dummy = pd.concat([X_cata_hasnan_dummy,X_cata_nonan_dummy],axis=1)
    return X_cata_dummy
    
#temp = drop_col(X,drop_col_inp)

# %%
def Feature_Engi(X):
    drop_col_inp = ['MiscFeature']
    dataX = drop_col(X, drop_col_inp)
    X_cata, X_num = X_classify(dataX)
#    X_cata_dummy = cata_process(X_cata)
    return X_num

X_cata_dummy = Feature_Engi(X)
X_cata_dummy.head()
# Out:
# ['MiscFeature']
#    MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0          60         65.0     8450            7            5       2003
# 1          20         80.0     9600            6            8       1976
# 2          60         68.0    11250            7            5       2001
# 3          70         60.0     9550            7            5       1915
# 4          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          2003       196.0         706           0        150          856
# 1          1976         0.0         978           0        284         1262
# 2          2002       162.0         486           0        434          920
# 3          1970         0.0         216           0        540          756
# 4          2000       350.0         655           0        490         1145
#
# ...

# %%
X_new = pd.concat([X_num, X_cata_dummy],axis=1)

# %%
pd.options.display.max_columns = 60
X_new.fillna(0,inplace=True)
X_cata_dummy.fillna(0,inplace=True)
# Out:
# /Users/yaoyao/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4239: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   **kwargs

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
def LNGRTrain(X,Y):
    
    (X_train,X_test,Y_train,Y_test) = train_test_split(X,Y,random_state = 1)
    gr = LinearRegression(normalize=False).fit(X_train,Y_train)
    return gr, X_test, Y_test


def RidgeTrain(X,Y):
    (X_train,X_test,Y_train,Y_test) = train_test_split(X,Y,random_state = 1)
    gr = Ridge(alpha=50).fit(X_train,Y_train)
    return gr, X_test, Y_test

def LaasoTrain(X,Y):
    (X_train,X_test,Y_train,Y_test) = train_test_split(X,Y,random_state = 1)
    gr = Lasso(alpha=2,max_iter=100000).fit(X_train,Y_train)
    return gr, X_test, Y_test

def LaasoNormTrain(X,Y):
    (X_train,X_test,Y_train,Y_test) = train_test_split(X,Y,random_state = 1)
    Scaler = StandardScaler().fit(X_train)
    X_train_Scaled = Scaler.transform(X_train)
    X_test_Scaled = Scaler.transform(X_test)
    gr = Lasso(alpha=2,max_iter=100000).fit(X_train_Scaled,Y_train)
    return gr, X_test_Scaled, Y_test

def LNGRNormTrain(X,Y):
    (X_train,X_test,Y_train,Y_test) = train_test_split(X,Y,random_state = 1)
    Scaler = MinMaxScaler().fit(X_train)
    X_train_Scaled = Scaler.transform(X_train)
    X_test_Scaled = Scaler.transform(X_test)
    gr = LinearRegression(fit_intercept=False).fit(X_train_Scaled,Y_train)
    return gr, X_test_Scaled, Y_test


def KNBTrain(X,Y):
    (X_train,X_test,Y_train,Y_test) = train_test_split(X,Y,random_state = 1)
    gr = KNeighborsRegressor(n_neighbors=7,leaf_size=50).fit(X_train,Y_train)
    return gr, X_test, Y_test
    
def GNBTrain(X,Y):
    (X_train,X_test,Y_train,Y_test) = train_test_split(X,Y,random_state = 1)
    gr = GaussianNB().fit(X_train,Y_train)
    return gr, X_test, Y_test

def SVCTrain(X,Y):
    (X_train,X_test,Y_train,Y_test) = train_test_split(X,Y,random_state = 1)
    gr = SVC(kernel='rbf',gamma='scale').fit(X_train,Y_train)
    return gr, X_test, Y_test

# %%
gr,xtest, ytest = LNGRTrain(X2,Y)
y_predict = gr.predict(xtest)
regression.r2_score(ytest,y_predict)
# Out:
# 0.8657734919592847

# %%
gr,xtest, ytest = LNGRNormTrain(X2,Y)
y_predict = gr.predict(xtest)
regression.r2_score(ytest,y_predict)
# Out:
# 0.8659796401350228

# %%
y_predict = gr.predict(xtest)
from sklearn.metrics import regression

regression.r2_score(ytest,y_predict)
# Out:
# 0.8657734919592847

# %%
gr,xtest, ytest = RidgeTrain(X2,Y)
y_predict = gr.predict(xtest)
regression.r2_score(ytest,y_predict)
# Out:
# 0.8672193232313525

# %%
gr,xtest, ytest = LaasoTrain(X2,Y)
y_predict = gr.predict(xtest)
regression.r2_score(ytest,y_predict)
# Out:
# 0.8743071804117116

# %%
gr,xtest, ytest = LaasoNormTrain(X2,Y)
y_predict = gr.predict(xtest)
regression.r2_score(ytest,y_predict)
# Out:
# 0.8714715723353623

# %%
gr,xtest, ytest = LaasoNormTrain(X_new,Y)
y_predict = gr.predict(xtest)
regression.r2_score(ytest,y_predict)
# Out:
# 0.8724385309682484

# %%
gr,xtest, ytest = KNBTrain(X2,Y)
y_predict = gr.predict(xtest)
regression.r2_score(ytest,y_predict)
# Out:
# 0.635938366028989

# %%
# Out:
# 0.568878690287067

# %%
# Out:
# -0.09445276969853733

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.model_selection import learning_curve
from sklearn.model_selection import ShuffleSplit

def plot_learning_curve(estimator, title, X, y, ylim=None, cv=None,
                        n_jobs=None, train_sizes=np.linspace(.1, 1.0, 5)):
    """
    Generate a simple plot of the test and training learning curve.

    Parameters
    ----------
    estimator : object type that implements the "fit" and "predict" methods
        An object of that type which is cloned for each validation.

    title : string
        Title for the chart.

    X : array-like, shape (n_samples, n_features)
        Training vector, where n_samples is the number of samples and
        n_features is the number of features.

    y : array-like, shape (n_samples) or (n_samples, n_features), optional
        Target relative to X for classification or regression;
        None for unsupervised learning.

    ylim : tuple, shape (ymin, ymax), optional
        Defines minimum and maximum yvalues plotted.

    cv : int, cross-validation generator or an iterable, optional
        Determines the cross-validation splitting strategy.
        Possible inputs for cv are:
          - None, to use the default 3-fold cross-validation,
          - integer, to specify the number of folds.
          - :term:`CV splitter`,
          - An iterable yielding (train, test) splits as arrays of indices.

        For integer/None inputs, if ``y`` is binary or multiclass,
        :class:`StratifiedKFold` used. If the estimator is not a classifier
        or if ``y`` is neither binary nor multiclass, :class:`KFold` is used.

        Refer :ref:`User Guide <cross_validation>` for the various
        cross-validators that can be used here.

    n_jobs : int or None, optional (default=None)
        Number of jobs to run in parallel.
        ``None`` means 1 unless in a :obj:`joblib.parallel_backend` context.
        ``-1`` means using all processors. See :term:`Glossary <n_jobs>`
        for more details.

    train_sizes : array-like, shape (n_ticks,), dtype float or int
        Relative or absolute numbers of training examples that will be used to
        generate the learning curve. If the dtype is float, it is regarded as a
        fraction of the maximum size of the training set (that is determined
        by the selected validation method), i.e. it has to be within (0, 1].
        Otherwise it is interpreted as absolute sizes of the training sets.
        Note that for classification the number of samples usually have to
        be big enough to contain at least one sample from each class.
        (default: np.linspace(0.1, 1.0, 5))
    """
    plt.figure()
    plt.title(title)
    if ylim is not None:
        plt.ylim(*ylim)
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes)
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    plt.grid()

    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Cross-validation score")

    plt.legend(loc="best")
    return plt



title = "Learning Curves (Naive Bayes)"
# Cross validation with 100 iterations to get smoother mean test and train
# score curves, each time with 20% data randomly selected as a validation set.
cv = ShuffleSplit(n_splits=20, test_size=0.2, random_state=0)

estimator = Lasso(alpha=2,max_iter=10000)
plot_learning_curve(estimator, title, X2, Y, ylim=(0.7, 1.01), cv=cv, n_jobs=4)

plt.show()
# Out:
# <module 'matplotlib.pyplot' from '/Users/yaoyao/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py'>
